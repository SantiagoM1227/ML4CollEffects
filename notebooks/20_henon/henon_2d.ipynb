# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import sys
import time
import os
from tensorflow import keras
from tensorflow.keras import Model
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_4978/1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: User cancelled dfs_ephemeral authorization

# %%
# !pip install xsuite
# Out:
# Collecting xsuite
#   Downloading xsuite-0.48.4-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (2.0 kB)
# Collecting xtrack==0.101.4 (from xsuite)
#   Downloading xtrack-0.101.4.tar.gz (759 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 759.1/759.1 kB 31.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting xfields==0.25.15 (from xsuite)
#   Downloading xfields-0.25.15.tar.gz (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.2/240.2 kB 18.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting xcoll==0.9.11 (from xsuite)
#   Downloading xcoll-0.9.11-py3-none-any.whl.metadata (3.1 kB)
# Collecting xobjects==0.5.15 (from xsuite)
#   Downloading xobjects-0.5.15.tar.gz (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 6.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting xdeps==0.10.15 (from xsuite)
#   Downloading xdeps-0.10.15-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (909 bytes)
# Collecting xpart==0.23.9 (from xsuite)
#   Downloading xpart-0.23.9.tar.gz (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.6/51.6 kB 3.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting meson (from xcoll==0.9.11->xsuite)
#   Downloading meson-1.10.2-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: numpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from xcoll==0.9.11->xsuite) (2.0.2)
# Requirement already satisfied: pandas>=1.4 in /usr/local/lib/python3.12/dist-packages (from xcoll==0.9.11->xsuite) (2.2.2)
# Collecting ruamel-yaml>=0.17.31 (from xcoll==0.9.11->xsuite)
#   Downloading ruamel_yaml-0.19.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: lark in /usr/local/lib/python3.12/dist-packages (from xdeps==0.10.15->xsuite) (1.3.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from xdeps==0.10.15->xsuite) (1.16.3)
# Requirement already satisfied: cython in /usr/local/lib/python3.12/dist-packages (from xdeps==0.10.15->xsuite) (3.0.12)
# Requirement already satisfied: cffi in /usr/local/lib/python3.12/dist-packages (from xobjects==0.5.15->xsuite) (2.0.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from xtrack==0.101.4->xsuite) (4.67.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from xtrack==0.101.4->xsuite) (2.32.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4->xcoll==0.9.11->xsuite) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4->xcoll==0.9.11->xsuite) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4->xcoll==0.9.11->xsuite) (2025.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi->xobjects==0.5.15->xsuite) (3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->xtrack==0.101.4->xsuite) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->xtrack==0.101.4->xsuite) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->xtrack==0.101.4->xsuite) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->xtrack==0.101.4->xsuite) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4->xcoll==0.9.11->xsuite) (1.17.0)
# Downloading xsuite-0.48.4-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 79.3 MB/s eta 0:00:00:00:0100:01
# Downloading xcoll-0.9.11-py3-none-any.whl (457 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 457.4/457.4 kB 31.6 MB/s eta 0:00:00
# Downloading xdeps-0.10.15-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (873 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 873.9/873.9 kB 44.5 MB/s eta 0:00:00
# Downloading ruamel_yaml-0.19.1-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.1/118.1 kB 9.2 MB/s eta 0:00:00
# Downloading meson-1.10.2-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 48.7 MB/s eta 0:00:00
# Building wheels for collected packages: xfields, xobjects, xpart, xtrack
#   Building wheel for xfields (pyproject.toml) ... done
#   Created wheel for xfields: filename=xfields-0.25.15-py3-none-any.whl size=224536 sha256=756aba6aab98961b1cd66b0d67c99ccaff4f30fda071f5603541174fd4030e4f
#   Stored in directory: /root/.cache/pip/wheels/df/5d/5d/19ef1755a1004765219b6ce7a0bee9e984e69192ad8986ca69
#   Building wheel for xobjects (pyproject.toml) ... done
#   Created wheel for xobjects: filename=xobjects-0.5.15-py3-none-any.whl size=67537 sha256=130f143dc073ea8a9bb3c1be54e6afced721894827410d12dadfd65dfe37e9ae
#   Stored in directory: /root/.cache/pip/wheels/3c/e5/df/06f7c837e8530d8d31537cbe8d1c820c625e6289dc61256917
#   Building wheel for xpart (pyproject.toml) ... done
#   Created wheel for xpart: filename=xpart-0.23.9-py3-none-any.whl size=63226 sha256=f1f74819feae22718c235846a82e155f2e54521b74cc986cdf3e8e56248aee2b
#   Stored in directory: /root/.cache/pip/wheels/ca/55/60/472116fe37b306b7e6d0d9d1529fb65cd40fdcded6fcac3d5e
#   Building wheel for xtrack (pyproject.toml) ... done
#   Created wheel for xtrack: filename=xtrack-0.101.4-py3-none-any.whl size=587536 sha256=57749a0bb02f0ed4c2b990bb99c4c4cf42be5022ac9dd4db28b7d1a5f0ad2a7d
#   Stored in directory: /root/.cache/pip/wheels/b4/e5/18/77cc0faed598462da09ff13f7bc961070377da9aaa50951729
# Successfully built xfields xobjects xpart xtrack
# Installing collected packages: ruamel-yaml, meson, xobjects, xdeps, xtrack, xpart, xfields, xcoll, xsuite
# Successfully installed meson-1.10.2 ruamel-yaml-0.19.1 xcoll-0.9.11 xdeps-0.10.15 xfields-0.25.15 xobjects-0.5.15 xpart-0.23.9 xsuite-0.48.4 xtrack-0.101.4

# %%
#import useful libraries
import numpy as np  # arrays and math
import matplotlib.pyplot as plt  # plots
import xtrack as xt  # tracking module of Xsuite
#%matplotlib widget

def plot_phase_space_with_profiles(x_array, px_array, title="",axis_labels = None, label=None, bins=120, difference=False)->None:
    fig = plt.figure(figsize=(10, 8))
    gs = fig.add_gridspec(
        2, 2,
        width_ratios=(4, 1.3),
        height_ratios=(1.3, 4),
        hspace=0.05,
        wspace=0.05
    )

    ax_histx = fig.add_subplot(gs[0, 0])
    ax_scatter = fig.add_subplot(gs[1, 0])
    ax_histpx = fig.add_subplot(gs[1, 1])

    # Scatter
    number_of_plots = len(x_array) if isinstance(x_array, list) else 1
    if number_of_plots > 1:
        for i in range(number_of_plots):
            x = x_array[i]
            px = px_array[i]
            lbl = label[i] if label is not None else None
            ax_scatter.scatter(x, px, s=2, alpha=0.4, label=lbl)
    else:
        x = x_array if not isinstance(x_array, list) else x_array[0]
        px = px_array if not isinstance(px_array, list) else px_array[0]
   
    ax_scatter.set_xlabel("x") if axis_labels is None else ax_scatter.set_xlabel(axis_labels[0])
    ax_scatter.set_ylabel("px") if axis_labels is None else ax_scatter.set_ylabel(axis_labels[1])
    if label is not None:
        ax_scatter.legend()

    # x profile
    if number_of_plots > 1:
        for i in range(number_of_plots):
            x = x_array[i]
            lbl = label[i] if label is not None else None
            ax_histx.hist(x, bins=bins, alpha=0.4, label=lbl)
            if difference and i == 1:  # If difference is True, plot the difference for the second dataset
                x_diff = x - (x_array[0] if not isinstance(x_array[0], list) else x_array[0][i])
                ax_histx.hist(x_diff, bins=bins, alpha=0.4, label=f"{lbl} Difference")
            
    else:        
        x = x_array if not isinstance(x_array, list) else x_array[0]
        ax_histx.hist(x, bins=bins, alpha=0.4)
    
    ax_histx.set_ylabel("count")
    ax_histx.tick_params(axis="x", labelbottom=False) 

    # px profile
    if number_of_plots > 1:
        for i in range(number_of_plots):
            px = px_array[i]
            lbl = label[i] if label is not None else None
            ax_histpx.hist(px, bins=bins, orientation="horizontal", alpha=0.4, label=lbl)
            if difference and i == 1:  # If difference is True, plot the difference for the second dataset
                px_diff = px - (px_array[0] if not isinstance(px_array[0], list) else px_array[0][i])
                ax_histpx.hist(px_diff, bins=bins, orientation="horizontal", alpha=0.4, label=f"{lbl} Difference")
    else:
        px = px_array if not isinstance(px_array, list) else px_array[0]
        ax_histpx.hist(px, bins=bins, orientation="horizontal", alpha=0.4)

    ax_histpx.set_xlabel("count")
    ax_histpx.tick_params(axis="y", labelleft=False)

    fig.suptitle(title)
    plt.show()


##################################

print('xtrack version', xt.__version__)

# Reference energy


part = xt.Particles(mass0=xt.PROTON_MASS_EV, p0c=1e9)  # Mass eV/c^2 Momentum in eV/c

# Element geometry
env=xt.Environment()
env.vars.default_to_zero = True
env['l_mq'] = 0.4


env.new('mq', xt.Quadrupole, length='l_mq')
env.new('qf1', 'mq', k1='kf1') # Focusing quadrupole  k1>0
env.new('qf2', 'mq', k1='kf2') # Focusing quadrupole  k1>0
env.new('qd1', 'mq', k1='kd1') # De-focusing quadrupole k1<0
#Markers
env.new("start_cell",xt.Marker)
env.new("end_cell",xt.Marker)


line = env.new_line(
    length=4, # 4 m length
    components=[
    env.place('start_cell', at=0),
    env.place('qf1', at=1),
    env.place('qd1', at=2),   # refer to the center by default
    env.place('qf2', at=3),
    env.place('end_cell',at=4),
    ]
)
line.particle_ref=part
line.build_tracker()   


kf1 = 1.0; kd1 = -1.0 ; kf2 = 1.0

env['kf1'] = kf1
env['kd1'] = kd1
env['kf2'] = kf2

rng = np.random.default_rng(56)
n_particles = 50000

p0 = line.build_particles(
    x     = rng.normal(0.0, 1e-3, n_particles),
    y     = rng.normal(0.0, 1e-3, n_particles),
    zeta  = rng.normal(0.0, 1e-3, n_particles),
    px    = rng.normal(0.0, 1e-3, n_particles),
    py    = rng.normal(0.0, 1e-3, n_particles),
    delta = rng.normal(0.0, 1e-4, n_particles)
)
line.track(p0, turn_by_turn_monitor="ONE_TURN_EBE")





def sample_initial_conditions(n_particles: int, rng: np.random.Generator) -> np.ndarray:
    x     = rng.normal(0.0, 1e-3, n_particles)
    y     = rng.normal(0.0, 1e-3, n_particles)
    zeta  = rng.normal(0.0, 1e-3, n_particles)
    px    = rng.normal(0.0, 1e-3, n_particles)
    py    = rng.normal(0.0, 1e-3, n_particles)
    delta = rng.normal(0.0, 1e-4, n_particles)

    ## it must be separated as {[x0,y0,zeta0,px0,py0,delta0], [x1,y1,zeta1,px1,py1,delta1], ...} -> column stack

    return np.column_stack([x, y, zeta, px, py, delta]).astype(np.float64)

def particles_to_6d(particles: xt.Particles) -> np.ndarray:
    # Henon order: [q, p] = [x, y, zeta, px, py, delta]
    return np.column_stack([
        np.array(particles.x),
        np.array(particles.y),
        np.array(particles.zeta),
        np.array(particles.px),
        np.array(particles.py),
        np.array(particles.delta),
    ]).astype(np.float64)


def data_builder(line: xt.Line, 
                 env,
                 total_particles=50000,
                 seed=42,
                 kf1_range=(0.2, 1.5),
                 kd1_range=(-2.5, -0.2),
                 kf2_range=(0.2, 1.5),
                 quad_iterations=1,
                 save_params=True) -> dict:
    
    rng = np.random.default_rng(seed)
    X_all, Y_all = [], []
    sampled_params = []

    for _ in range(quad_iterations):
        kf1 = rng.uniform(*kf1_range)
        kd1 = rng.uniform(*kd1_range)
        kf2 = rng.uniform(*kf2_range)

        env['kf1'] = kf1
        env['kd1'] = kd1
        env['kf2'] = kf2

        z0 = sample_initial_conditions(total_particles, rng)

        p = line.build_particles(
            x=z0[:, 0],
            y=z0[:, 1],
            zeta=z0[:, 2],
            px=z0[:, 3],
            py=z0[:, 4],
            delta=z0[:, 5],
        )

        line.track(p)

        z1 = particles_to_6d(p)

        mu = np.tile(np.array([kf1, kd1, kf2], dtype=np.float64), (total_particles, 1))
        X_batch = np.hstack([z0, mu]) if save_params else z0
        Y_batch = z1

        X_all.append(X_batch)
        Y_all.append(Y_batch)
        sampled_params.append((kf1, kd1, kf2))

    X = np.vstack(X_all)
    Y = np.vstack(Y_all)

    perm = rng.permutation(X.shape[0])   # fixed
    X = X[perm]
    Y = Y[perm]

    np.savez("xsuite_dataset.npz", X=X, Y=Y)
    print("Dataset shapes: X =", X.shape, ", Y =", Y.shape)
    print("Dataset saved to xsuite_dataset.npz")

    return {"X": X, "Y": Y, "params": sampled_params}

def build_operator_dataset(
    line,
    env,
    n_samples=2000,
    particles_per_sample=4000,
    seed=42,
    kf1_range=(0.1, 2.0),
    kd1_range=(-4.5, -0.05),
    kf2_range=(0.1, 2.0),
    ):
    rng = np.random.default_rng(seed)

    X_samples = []
    Y_samples = []
    MU_samples = []

    for _ in range(n_samples):
        kf1 = rng.uniform(*kf1_range)
        kd1 = rng.uniform(*kd1_range)
        kf2 = rng.uniform(*kf2_range)

        env["kf1"] = kf1
        env["kd1"] = kd1
        env["kf2"] = kf2

        z0 = sample_initial_conditions(particles_per_sample, rng)

        p = line.build_particles(
            x=z0[:, 0],
            y=z0[:, 1],
            zeta=z0[:, 2],
            px=z0[:, 3],
            py=z0[:, 4],
            delta=z0[:, 5],
        )
        line.track(p)
        z1 = particles_to_6d(p)

        X_samples.append(z0.astype(np.float32))          # [Np, 6]
        Y_samples.append(z1.astype(np.float32))          # [Np, 6]
        MU_samples.append(np.array([kf1, kd1, kf2], dtype=np.float32))

    X_samples = np.stack(X_samples, axis=0)   # [Ns, Np, 6]
    Y_samples = np.stack(Y_samples, axis=0)   # [Ns, Np, 6]
    MU_samples = np.stack(MU_samples, axis=0) # [Ns, 3]

    np.savez("xsuite_operator_dataset.npz", X=X_samples, Y=Y_samples, MU=MU_samples)
    print("Saved:", X_samples.shape, Y_samples.shape, MU_samples.shape)
    
    
# in generate_dataset.py
build_operator_dataset(
        line,
        env,
        n_samples=200,
        particles_per_sample=4000,
        seed=42,
        kf1_range=(0.1, 2.0),
        kd1_range=(-4.5, -0.05),
        kf2_range=(0.1, 2.0),
    )

data = data_builder(line, 
             env, 
             total_particles=50000, 
             seed=42, 
             kf1_range=(0.1, 2), 
             kd1_range=(-4.5, -0.05), 
             kf2_range=(0.1, 2), 
             quad_iterations=1,
             save_params=False)


z_in_raw = data["X"]
z_out_raw = data["Y"]


x_data_generator = z_out_raw[:, 0]
px_data_generator = z_out_raw[:, 3]
y_data_generator = z_out_raw[:, 1]
py_data_generator = z_out_raw[:, 4]
zeta_data_generator = z_out_raw[:, 2]
delta_data_generator = z_out_raw[:, 5]

x = np.array(p0.x)
px = np.array(p0.px)
y = np.array(p0.y)
py = np.array(p0.py)
zeta = np.array(p0.zeta)
delta = np.array(p0.delta)

x_array = [x, x_data_generator]
px_array = [px, px_data_generator]
y_array = [y, y_data_generator]
py_array = [py, py_data_generator]
zeta_array = [zeta, zeta_data_generator]
delta_array = [delta, delta_data_generator]

label = ["Original", "Data Generator"]
x_axis_array = [x_array, y_array, zeta_array]
px_axis_array = [px_array, py_array, delta_array]

axis_labels = [["x", "px"] , ["y", "py"], ["zeta", "delta"]]

axis_index = 1 # 0 for x-px, 1 for y-py, 2 for zeta-delta

for axis_index in range(3):
    plot_phase_space_with_profiles(x_axis_array[axis_index], px_axis_array[axis_index], title=f"Transport for kf1={env['kf1']}, kd1={env['kd1']}, kf2={env['kf2']}", axis_labels=axis_labels[axis_index], label=label, difference=False)
# Out:
# xtrack version 0.101.4
# Saved: (200, 4000, 6) (200, 4000, 6) (200, 3)
# Dataset shapes: X = (50000, 6) , Y = (50000, 6)
# Dataset saved to xsuite_dataset.npz

# %%
tf.keras.backend.set_floatx('float64')
keras.backend.set_floatx('float64')

# %%
###### Henon Map
def HenonMap(X, Y, mu, Win, Wout, bin, eta):
    with tf.GradientTape() as tape:
        tape.watch(Y)
        Ylast = (Y - 0.0) / np.pi
        Y_V = tf.concat([Ylast, mu], axis=1) if mu is not None else Ylast
        hidden = tf.math.tanh(tf.linalg.matmul(Y_V, Win) + bin)   # bin shape [ni]
        V = tf.linalg.matmul(hidden, Wout)                        # [batch, 1]

    Xout = Y + eta                                               # eta shape [dim]
    Yout = -X + tape.gradient(V, Y)
    return Xout, Yout
'''Define a Henon layer'''
class HenonLayer(layers.Layer):
    def __init__(self, ni, dim=3, mu_dim=0):
        super().__init__()
        self.dim = dim
        self.mu_dim = mu_dim
        self.ni = ni
        self.init = tf.initializers.GlorotNormal()

    def build(self, input_shape):
        in_dim = self.dim + self.mu_dim

        self.Win = self.add_weight(
            name="Win",
            shape=(in_dim, self.ni),
            initializer=self.init,
            dtype=tf.float64,
            trainable=True,
        )
        self.Wout = self.add_weight(
            name="Wout",
            shape=(self.ni, 1),
            initializer=self.init,
            dtype=tf.float64,
            trainable=True,
        )
        self.bin = self.add_weight(
            name="bin",
            shape=(self.ni,),
            initializer="zeros",
            dtype=tf.float64,
            trainable=True,
        )
        self.eta = self.add_weight(
            name="eta",
            shape=(self.dim,),
            initializer="zeros",
            dtype=tf.float64,
            trainable=True,
        )
        super().build(input_shape)

    def call(self, z):
        d = self.dim
        x = z[:, :d]
        y = z[:, d:2*d]
        mu = z[:, 2*d:] if z.shape[1] > 2*d else None

        xnext, ynext = HenonMap(x, y, mu, self.Win, self.Wout, self.bin, self.eta)
        xnext, ynext = HenonMap(xnext, ynext, mu, self.Win, self.Wout, self.bin, self.eta)
        xnext, ynext = HenonMap(xnext, ynext, mu, self.Win, self.Wout, self.bin, self.eta)
        xnext, ynext = HenonMap(xnext, ynext, mu, self.Win, self.Wout, self.bin, self.eta)
        return tf.concat([xnext, ynext], axis=1)
    
'''Define a HenonNet'''
class HenonNet(Model):
    def __init__(self,unit_list,dim = 3):#
        super(HenonNet, self).__init__()
        self.N = len(unit_list)
        # Keep a Python list for easy iteration, but ALSO assign each
        # sublayer as an attribute on `self` so Keras will register it
        # as a tracked sublayer (and expose its variables).
        self.hlayers = []
        for i in range(self.N):
            ni = unit_list[i]
            hl = HenonLayer(ni, dim)
            # append to list for iteration
            self.hlayers.append(hl)
            # register as attribute so Keras sees it as a sublayer
            setattr(self, f"hl_{i}", hl)
    def call(self, r):
        rout = r
        for i in range(self.N):
            rout = self.hlayers[i](rout)
        return rout

# %%
def data_normalizer(data):
    '''
    
    the input is a dataframe phasespace with columns [x, y, zeta, px, py, delta] and shape [N, 6]
    
    each coordinate is normalized individually and the output is a dataframe of the same shape with the normalized coordinates, as well as the mean and std for each coordinate to be used in the inverse transformation
    
    '''
    X = data[:, :6] # only the phase space coordinates, not the parameters
    mean = np.mean(X, axis=0) # compute mean for each column shape [6,]
    std = np.std(X, axis=0) + 1e-12 # add small value to avoid division by zero shape [6,]
    normalized_data = (X - mean) / std #each column is normalized independently shape [N, 6]
    return normalized_data, mean, std 

data_denormalizer = lambda normalized, mean, std: normalized * std + mean

# %%
data = np.load("xsuite_dataset.npz")

X_raw = data["X"]  # shape (N, 6)
Y = data["Y"]  # shape (N, 6)

print("Original X shape:", X_raw.shape)
print("Original Y shape:", Y.shape)

Z = X_raw[:, :6] #(x,y, zeta, px, py, delta )
MU = X_raw[:, 6:9] # (mu_i)i=1:m

Z, Z_mean, Z_std = data_normalizer(Z)
Y, Y_mean, Y_std = data_normalizer(Y)

x_array = [Z[:, 0], Y[:, 0]]
px_array = [Z[:, 3], Y[:, 3]]

labels = ["Original", "Data Generator"]

plot_phase_space_with_profiles(x_array, px_array, title="Normalizded Phase Space", label=labels, difference=False)

x_denorm = data_denormalizer(Z[:, 0], Z_mean[0], Z_std[0])
px_denorm = data_denormalizer(Z[:, 3], Z_mean[3], Z_std[3])

x_denorm_array = [x_denorm, data_denormalizer(Y[:, 0], Y_mean[0], Y_std[0])]
px_denorm_array = [px_denorm, data_denormalizer(Y[:, 3], Y_mean[3], Y_std[3])]
plot_phase_space_with_profiles(x_denorm_array, px_denorm_array, title="Denormalized Phase Space", label=labels, difference=False)


print("MU shape:", MU.shape)

dimensions_to_train = [0] #0 = x,px/ 1 = y,py/ 2 = zeta, delta 
dimensions_to_train = dimensions_to_train + [i+3 for i in dimensions_to_train] 

list_train = [Z[:, i:i+1] for i in  dimensions_to_train]    
list_label = [Y[:, i:i+1] for i in dimensions_to_train]

Z_std_selected = Z_std[dimensions_to_train]
Z_mean_selected = Z_mean[dimensions_to_train]
Y_std_selected = Y_std[dimensions_to_train]
Y_mean_selected = Y_mean[dimensions_to_train]

data = tf.concat(list_train, axis = 1)
labels = tf.concat(list_label, axis = 1)

mse_initial = np.mean(np.abs((data - labels))**2)
print("Initial MSE:", mse_initial)

print("Training set shapes:", data.shape, labels.shape)
print("Test set shapes:",data.shape, labels.shape)
# Out:
# Original X shape: (50000, 6)
# Original Y shape: (50000, 6)
# MU shape: (50000, 0)
# Initial MSE: 2.6785405042428843
# Training set shapes: (50000, 2) (50000, 2)
# Test set shapes: (50000, 2) (50000, 2)

# %%
import tensorflow as tf



beta = tf.constant(10.0, dtype=tf.float64)   # how much more important tails are
gamma = tf.constant(5.0, dtype=tf.float64)  # how sharply weight grows
r_cap = tf.constant(3.0, dtype=tf.float64)  # cap the effective radius

def weighted_outer_mse(y_true, y_pred):
    x0 = Z_std[0]  # scale for x
    y0 = Z_std[1]  # scale for y
    zeta0 = Z_std[2]  # scale for zeta
    px0 = Z_std[3]  # scale for px
    py0 = Z_std[4]  # scale for py
    delta0 = Z_std[5]  # scale for delta
    
    y_true = tf.cast(y_true, tf.float64)
    y_pred = tf.cast(y_pred, tf.float64)

    half_index = y_true.shape[1] // 2
    x_pred = y_pred[:, :half_index] #shape [batch, dim]
    px_pred = y_pred[:, half_index:] #shape [batch, dim]
    
    r = tf.sqrt((x_pred / x0)**2 + (px_pred / px0)**2) # shape [batch, dim]
    

    # one combined radius per particle
    r_eff = tf.minimum(r, r_cap)

    # low weight in center, higher in tails
    w = 1.0 + beta * (r_eff / r_cap)**gamma

    # pointwise squared error in raw coordinates
    err2 = tf.reduce_sum(tf.square(y_pred - y_true), axis=1)

    return tf.reduce_mean(w * err2)

# %%
####### Train the HenonNet
def schedulerHenon(epoch): 
        if epoch < 100:
            return 1e-3 
        elif epoch < 300:
            return 6e-4 
        elif epoch < 400:
            return 2e-4 
        elif epoch < 500:
            return 5e-5 
        elif epoch < 1000:
            return 1e-5 
        elif epoch < 3000:
            return 4e-6 
        else:
            return 1e-6
ymean_tf = tf.constant(0., dtype = tf.float64)
ydiam_tf = tf.constant(np.pi, dtype = tf.float64)
#loss_fun = tf.keras.losses.MeanSquaredError()
sx = np.std(data[:, 0])
sp = np.std(data[:, 1])
loss_fun = weighted_outer_mse
test_model = HenonNet([5,5,5], dim = 1)
test_model = HenonNet([5, 5, 5], dim=1)
dummy = tf.zeros((1, 2), dtype=tf.float64)
_ = test_model(dummy)
print(len(test_model.trainable_variables))
# quick check: show trainable variables before fitting
print('trainable variables count BEFORE compile:', len(test_model.trainable_variables))
for v in test_model.trainable_variables[:10]:
    print(v.name, v.shape)
test_model.compile(optimizer = keras.optimizers.Adam(learning_rate = 1e-4),loss = loss_fun)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=10,
    min_delta=5e-6,
    restore_best_weights=True,
    verbose=1
)
callback = tf.keras.callbacks.LearningRateScheduler(schedulerHenon)
h = test_model.fit(data, labels, batch_size = 1000, epochs = 3000, validation_split=0.4,verbose=1,callbacks=[callback, early_stop])
# Out:
# 12
# trainable variables count BEFORE compile: 12
# Win (1, 5)
# Wout (5, 1)
# bin (5,)
# eta (1,)
# Win (1, 5)
# Wout (5, 1)
# bin (5,)
# eta (1,)
# Win (1, 5)
# Wout (5, 1)
# Epoch 1/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 55.9366 - val_loss: 53.4756 - learning_rate: 1.0000e-03
# Epoch 2/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 53.7619 - val_loss: 51.0778 - learning_rate: 1.0000e-03
# Epoch 3/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 51.0287 - val_loss: 48.0824 - learning_rate: 1.0000e-03
# Epoch 4/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 47.6405 - val_loss: 44.4241 - learning_rate: 1.0000e-03
# Epoch 5/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 43.6001 - val_loss: 40.1595 - learning_rate: 1.0000e-03
# Epoch 6/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 39.0265 - val_loss: 35.5754 - learning_rate: 1.0000e-03
# Epoch 7/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 34.2913 - val_loss: 31.0844 - learning_rate: 1.0000e-03
# Epoch 8/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 29.8773 - val_loss: 27.1437 - learning_rate: 1.0000e-03
# Epoch 9/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 26.1807 - val_loss: 24.0445 - learning_rate: 1.0000e-03
# Epoch 10/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 23.3488 - val_loss: 21.7486 - learning_rate: 1.0000e-03
# Epoch 11/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 21.2432 - val_loss: 20.0222 - learning_rate: 1.0000e-03
# Epoch 12/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 19.6203 - val_loss: 18.6223 - learning_rate: 1.0000e-03
# Epoch 13/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 18.2769 - val_loss: 17.3952 - learning_rate: 1.0000e-03
# Epoch 14/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 17.0797 - val_loss: 16.2875 - learning_rate: 1.0000e-03
# Epoch 15/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 15.9910 - val_loss: 15.2533 - learning_rate: 1.0000e-03
# Epoch 16/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 14.9774 - val_loss: 14.2879 - learning_rate: 1.0000e-03
# Epoch 17/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 14.0326 - val_loss: 13.3790 - learning_rate: 1.0000e-03
# Epoch 18/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 13.1454 - val_loss: 12.5264 - learning_rate: 1.0000e-03
# Epoch 19/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 12.3136 - val_loss: 11.7254 - learning_rate: 1.0000e-03
# Epoch 20/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 11.5316 - val_loss: 10.9739 - learning_rate: 1.0000e-03
# Epoch 21/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 10.7973 - val_loss: 10.2679 - learning_rate: 1.0000e-03
# Epoch 22/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 10.1074 - val_loss: 9.6034 - learning_rate: 1.0000e-03
# Epoch 23/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 9.4581 - val_loss: 8.9788 - learning_rate: 1.0000e-03
# Epoch 24/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 8.8472 - val_loss: 8.3917 - learning_rate: 1.0000e-03
# Epoch 25/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 8.2731 - val_loss: 7.8372 - learning_rate: 1.0000e-03
# Epoch 26/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 7.7314 - val_loss: 7.3177 - learning_rate: 1.0000e-03
# Epoch 27/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 7.2231 - val_loss: 6.8284 - learning_rate: 1.0000e-03
# Epoch 28/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 6.7437 - val_loss: 6.3692 - learning_rate: 1.0000e-03
# Epoch 29/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.2932 - val_loss: 5.9382 - learning_rate: 1.0000e-03
# Epoch 30/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.8698 - val_loss: 5.5330 - learning_rate: 1.0000e-03
# Epoch 31/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.4725 - val_loss: 5.1518 - learning_rate: 1.0000e-03
# Epoch 32/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 5.0981 - val_loss: 4.7956 - learning_rate: 1.0000e-03
# Epoch 33/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.7479 - val_loss: 4.4610 - learning_rate: 1.0000e-03
# Epoch 34/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.4193 - val_loss: 4.1480 - learning_rate: 1.0000e-03
# Epoch 35/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.1118 - val_loss: 3.8551 - learning_rate: 1.0000e-03
# Epoch 36/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.8242 - val_loss: 3.5824 - learning_rate: 1.0000e-03
# Epoch 37/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.5560 - val_loss: 3.3284 - learning_rate: 1.0000e-03
# Epoch 38/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 3.3064 - val_loss: 3.0911 - learning_rate: 1.0000e-03
# Epoch 39/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 3.0737 - val_loss: 2.8714 - learning_rate: 1.0000e-03
# Epoch 40/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 2.8583 - val_loss: 2.6671 - learning_rate: 1.0000e-03
# Epoch 41/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 2.6583 - val_loss: 2.4787 - learning_rate: 1.0000e-03
# Epoch 42/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.4735 - val_loss: 2.3051 - learning_rate: 1.0000e-03
# Epoch 43/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.3031 - val_loss: 2.1451 - learning_rate: 1.0000e-03
# Epoch 44/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 2.1464 - val_loss: 1.9979 - learning_rate: 1.0000e-03
# Epoch 45/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 2.0022 - val_loss: 1.8630 - learning_rate: 1.0000e-03
# Epoch 46/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.8703 - val_loss: 1.7398 - learning_rate: 1.0000e-03
# Epoch 47/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.7496 - val_loss: 1.6275 - learning_rate: 1.0000e-03
# Epoch 48/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.6399 - val_loss: 1.5249 - learning_rate: 1.0000e-03
# Epoch 49/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.5394 - val_loss: 1.4327 - learning_rate: 1.0000e-03
# Epoch 50/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.4487 - val_loss: 1.3484 - learning_rate: 1.0000e-03
# Epoch 51/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.3661 - val_loss: 1.2722 - learning_rate: 1.0000e-03
# Epoch 52/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 1.2913 - val_loss: 1.2031 - learning_rate: 1.0000e-03
# Epoch 53/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 1.2235 - val_loss: 1.1409 - learning_rate: 1.0000e-03
# Epoch 54/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.1620 - val_loss: 1.0852 - learning_rate: 1.0000e-03
# Epoch 55/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.1069 - val_loss: 1.0341 - learning_rate: 1.0000e-03
# Epoch 56/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.0566 - val_loss: 0.9886 - learning_rate: 1.0000e-03
# Epoch 57/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.0114 - val_loss: 0.9474 - learning_rate: 1.0000e-03
# Epoch 58/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.9704 - val_loss: 0.9102 - learning_rate: 1.0000e-03
# Epoch 59/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.9333 - val_loss: 0.8764 - learning_rate: 1.0000e-03
# Epoch 60/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.8997 - val_loss: 0.8461 - learning_rate: 1.0000e-03
# Epoch 61/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.8692 - val_loss: 0.8185 - learning_rate: 1.0000e-03
# Epoch 62/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.8416 - val_loss: 0.7934 - learning_rate: 1.0000e-03
# Epoch 63/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.8162 - val_loss: 0.7707 - learning_rate: 1.0000e-03
# Epoch 64/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.7932 - val_loss: 0.7501 - learning_rate: 1.0000e-03
# Epoch 65/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.7723 - val_loss: 0.7311 - learning_rate: 1.0000e-03
# Epoch 66/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.7532 - val_loss: 0.7136 - learning_rate: 1.0000e-03
# Epoch 67/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.7355 - val_loss: 0.6974 - learning_rate: 1.0000e-03
# Epoch 68/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.7191 - val_loss: 0.6829 - learning_rate: 1.0000e-03
# Epoch 69/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.7043 - val_loss: 0.6695 - learning_rate: 1.0000e-03
# Epoch 70/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.6905 - val_loss: 0.6571 - learning_rate: 1.0000e-03
# Epoch 71/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.6779 - val_loss: 0.6455 - learning_rate: 1.0000e-03
# Epoch 72/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.6661 - val_loss: 0.6348 - learning_rate: 1.0000e-03
# Epoch 73/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.6552 - val_loss: 0.6248 - learning_rate: 1.0000e-03
# Epoch 74/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.6449 - val_loss: 0.6160 - learning_rate: 1.0000e-03
# Epoch 75/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.6357 - val_loss: 0.6073 - learning_rate: 1.0000e-03
# Epoch 76/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.6268 - val_loss: 0.5992 - learning_rate: 1.0000e-03
# Epoch 77/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.6186 - val_loss: 0.5917 - learning_rate: 1.0000e-03
# Epoch 78/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.6110 - val_loss: 0.5848 - learning_rate: 1.0000e-03
# Epoch 79/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.6037 - val_loss: 0.5784 - learning_rate: 1.0000e-03
# Epoch 80/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5971 - val_loss: 0.5722 - learning_rate: 1.0000e-03
# Epoch 81/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.5907 - val_loss: 0.5666 - learning_rate: 1.0000e-03
# Epoch 82/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.5849 - val_loss: 0.5612 - learning_rate: 1.0000e-03
# Epoch 83/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5793 - val_loss: 0.5562 - learning_rate: 1.0000e-03
# Epoch 84/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5741 - val_loss: 0.5516 - learning_rate: 1.0000e-03
# Epoch 85/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5692 - val_loss: 0.5471 - learning_rate: 1.0000e-03
# Epoch 86/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5645 - val_loss: 0.5428 - learning_rate: 1.0000e-03
# Epoch 87/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5600 - val_loss: 0.5389 - learning_rate: 1.0000e-03
# Epoch 88/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5558 - val_loss: 0.5351 - learning_rate: 1.0000e-03
# Epoch 89/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5519 - val_loss: 0.5315 - learning_rate: 1.0000e-03
# Epoch 90/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.5480 - val_loss: 0.5281 - learning_rate: 1.0000e-03
# Epoch 91/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.5444 - val_loss: 0.5248 - learning_rate: 1.0000e-03
# Epoch 92/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5409 - val_loss: 0.5217 - learning_rate: 1.0000e-03
# Epoch 93/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5376 - val_loss: 0.5187 - learning_rate: 1.0000e-03
# Epoch 94/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5344 - val_loss: 0.5158 - learning_rate: 1.0000e-03
# Epoch 95/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.5313 - val_loss: 0.5131 - learning_rate: 1.0000e-03
# Epoch 96/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.5283 - val_loss: 0.5104 - learning_rate: 1.0000e-03
# Epoch 97/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5255 - val_loss: 0.5078 - learning_rate: 1.0000e-03
# Epoch 98/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5227 - val_loss: 0.5054 - learning_rate: 1.0000e-03
# Epoch 99/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5200 - val_loss: 0.5030 - learning_rate: 1.0000e-03
# Epoch 100/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5173 - val_loss: 0.5007 - learning_rate: 1.0000e-03
# Epoch 101/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5152 - val_loss: 0.4993 - learning_rate: 6.0000e-04
# Epoch 102/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5137 - val_loss: 0.4980 - learning_rate: 6.0000e-04
# Epoch 103/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5123 - val_loss: 0.4966 - learning_rate: 6.0000e-04
# Epoch 104/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5107 - val_loss: 0.4952 - learning_rate: 6.0000e-04
# Epoch 105/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5093 - val_loss: 0.4939 - learning_rate: 6.0000e-04
# Epoch 106/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.5078 - val_loss: 0.4926 - learning_rate: 6.0000e-04
# Epoch 107/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5063 - val_loss: 0.4913 - learning_rate: 6.0000e-04
# Epoch 108/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.5049 - val_loss: 0.4900 - learning_rate: 6.0000e-04
# Epoch 109/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.5035 - val_loss: 0.4887 - learning_rate: 6.0000e-04
# Epoch 110/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.5020 - val_loss: 0.4875 - learning_rate: 6.0000e-04
# Epoch 111/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5006 - val_loss: 0.4862 - learning_rate: 6.0000e-04
# Epoch 112/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.4992 - val_loss: 0.4849 - learning_rate: 6.0000e-04
# Epoch 113/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.4978 - val_loss: 0.4837 - learning_rate: 6.0000e-04
# Epoch 114/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.4966 - val_loss: 0.4825 - learning_rate: 6.0000e-04
# Epoch 115/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.4950 - val_loss: 0.4812 - learning_rate: 6.0000e-04
# Epoch 116/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.4936 - val_loss: 0.4799 - learning_rate: 6.0000e-04
# Epoch 117/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.4922 - val_loss: 0.4787 - learning_rate: 6.0000e-04
# Epoch 118/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.4908 - val_loss: 0.4775 - learning_rate: 6.0000e-04
# Epoch 119/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.4895 - val_loss: 0.4763 - learning_rate: 6.0000e-04
# Epoch 120/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.4881 - val_loss: 0.4751 - learning_rate: 6.0000e-04
# Epoch 121/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.4868 - val_loss: 0.4738 - learning_rate: 6.0000e-04
# Epoch 122/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.4854 - val_loss: 0.4726 - learning_rate: 6.0000e-04
# Epoch 123/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.4841 - val_loss: 0.4714 - learning_rate: 6.0000e-04
# Epoch 124/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.4827 - val_loss: 0.4702 - learning_rate: 6.0000e-04
# Epoch 125/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.4814 - val_loss: 0.4690 - learning_rate: 6.0000e-04
# Epoch 126/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.4801 - val_loss: 0.4678 - learning_rate: 6.0000e-04
# Epoch 127/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.4787 - val_loss: 0.4666 - learning_rate: 6.0000e-04
# Epoch 128/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.4773 - val_loss: 0.4654 - learning_rate: 6.0000e-04
# Epoch 129/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.4760 - val_loss: 0.4642 - learning_rate: 6.0000e-04
# Epoch 130/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.4747 - val_loss: 0.4630 - learning_rate: 6.0000e-04
# Epoch 131/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.4734 - val_loss: 0.4618 - learning_rate: 6.0000e-04
# Epoch 132/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.4720 - val_loss: 0.4606 - learning_rate: 6.0000e-04
# Epoch 133/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.4707 - val_loss: 0.4594 - learning_rate: 6.0000e-04
# Epoch 134/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.4694 - val_loss: 0.4582 - learning_rate: 6.0000e-04
# Epoch 135/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.4680 - val_loss: 0.4570 - learning_rate: 6.0000e-04
# Epoch 136/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.4667 - val_loss: 0.4558 - learning_rate: 6.0000e-04
# Epoch 137/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.4654 - val_loss: 0.4546 - learning_rate: 6.0000e-04
# Epoch 138/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.4641 - val_loss: 0.4534 - learning_rate: 6.0000e-04
# Epoch 139/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.4628 - val_loss: 0.4522 - learning_rate: 6.0000e-04
# Epoch 140/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.4615 - val_loss: 0.4511 - learning_rate: 6.0000e-04
# Epoch 141/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.4602 - val_loss: 0.4498 - learning_rate: 6.0000e-04
# Epoch 142/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.4589 - val_loss: 0.4486 - learning_rate: 6.0000e-04
# Epoch 143/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.4576 - val_loss: 0.4474 - learning_rate: 6.0000e-04
# Epoch 144/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.4563 - val_loss: 0.4462 - learning_rate: 6.0000e-04
# Epoch 145/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.4550 - val_loss: 0.4450 - learning_rate: 6.0000e-04
# Epoch 146/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.4538 - val_loss: 0.4439 - learning_rate: 6.0000e-04
# Epoch 147/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.4523 - val_loss: 0.4426 - learning_rate: 6.0000e-04
# Epoch 148/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.4510 - val_loss: 0.4414 - learning_rate: 6.0000e-04
# Epoch 149/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.4497 - val_loss: 0.4403 - learning_rate: 6.0000e-04
# Epoch 150/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.4484 - val_loss: 0.4391 - learning_rate: 6.0000e-04
# Epoch 151/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.4471 - val_loss: 0.4378 - learning_rate: 6.0000e-04
# Epoch 152/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.4458 - val_loss: 0.4367 - learning_rate: 6.0000e-04
# Epoch 153/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.4445 - val_loss: 0.4355 - learning_rate: 6.0000e-04
# Epoch 154/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.4432 - val_loss: 0.4342 - learning_rate: 6.0000e-04
# Epoch 155/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.4419 - val_loss: 0.4330 - learning_rate: 6.0000e-04
# Epoch 156/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.4406 - val_loss: 0.4318 - learning_rate: 6.0000e-04
# Epoch 157/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.4393 - val_loss: 0.4306 - learning_rate: 6.0000e-04
# Epoch 158/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.4380 - val_loss: 0.4293 - learning_rate: 6.0000e-04
# Epoch 159/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.4366 - val_loss: 0.4281 - learning_rate: 6.0000e-04
# Epoch 160/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.4354 - val_loss: 0.4270 - learning_rate: 6.0000e-04
# Epoch 161/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.4340 - val_loss: 0.4257 - learning_rate: 6.0000e-04
# Epoch 162/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.4328 - val_loss: 0.4245 - learning_rate: 6.0000e-04
# Epoch 163/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.4314 - val_loss: 0.4232 - learning_rate: 6.0000e-04
# Epoch 164/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.4301 - val_loss: 0.4220 - learning_rate: 6.0000e-04
# Epoch 165/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.4288 - val_loss: 0.4208 - learning_rate: 6.0000e-04
# Epoch 166/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.4275 - val_loss: 0.4196 - learning_rate: 6.0000e-04
# Epoch 167/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.4262 - val_loss: 0.4184 - learning_rate: 6.0000e-04
# Epoch 168/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.4248 - val_loss: 0.4171 - learning_rate: 6.0000e-04
# Epoch 169/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.4235 - val_loss: 0.4159 - learning_rate: 6.0000e-04
# Epoch 170/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.4222 - val_loss: 0.4146 - learning_rate: 6.0000e-04
# Epoch 171/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.4209 - val_loss: 0.4134 - learning_rate: 6.0000e-04
# Epoch 172/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.4195 - val_loss: 0.4121 - learning_rate: 6.0000e-04
# Epoch 173/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.4182 - val_loss: 0.4108 - learning_rate: 6.0000e-04
# Epoch 174/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.4169 - val_loss: 0.4097 - learning_rate: 6.0000e-04
# Epoch 175/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.4156 - val_loss: 0.4083 - learning_rate: 6.0000e-04
# Epoch 176/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.4142 - val_loss: 0.4071 - learning_rate: 6.0000e-04
# Epoch 177/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.4129 - val_loss: 0.4058 - learning_rate: 6.0000e-04
# Epoch 178/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.4116 - val_loss: 0.4047 - learning_rate: 6.0000e-04
# Epoch 179/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.4103 - val_loss: 0.4033 - learning_rate: 6.0000e-04
# Epoch 180/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.4089 - val_loss: 0.4020 - learning_rate: 6.0000e-04
# Epoch 181/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.4076 - val_loss: 0.4007 - learning_rate: 6.0000e-04
# Epoch 182/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.4063 - val_loss: 0.3994 - learning_rate: 6.0000e-04
# Epoch 183/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.4049 - val_loss: 0.3983 - learning_rate: 6.0000e-04
# Epoch 184/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.4037 - val_loss: 0.3969 - learning_rate: 6.0000e-04
# Epoch 185/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.4022 - val_loss: 0.3956 - learning_rate: 6.0000e-04
# Epoch 186/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.4009 - val_loss: 0.3944 - learning_rate: 6.0000e-04
# Epoch 187/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3995 - val_loss: 0.3931 - learning_rate: 6.0000e-04
# Epoch 188/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3983 - val_loss: 0.3918 - learning_rate: 6.0000e-04
# Epoch 189/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3969 - val_loss: 0.3906 - learning_rate: 6.0000e-04
# Epoch 190/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.3955 - val_loss: 0.3891 - learning_rate: 6.0000e-04
# Epoch 191/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3941 - val_loss: 0.3879 - learning_rate: 6.0000e-04
# Epoch 192/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.3928 - val_loss: 0.3866 - learning_rate: 6.0000e-04
# Epoch 193/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.3915 - val_loss: 0.3855 - learning_rate: 6.0000e-04
# Epoch 194/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3902 - val_loss: 0.3842 - learning_rate: 6.0000e-04
# Epoch 195/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.3889 - val_loss: 0.3829 - learning_rate: 6.0000e-04
# Epoch 196/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3873 - val_loss: 0.3814 - learning_rate: 6.0000e-04
# Epoch 197/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.3861 - val_loss: 0.3801 - learning_rate: 6.0000e-04
# Epoch 198/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3848 - val_loss: 0.3788 - learning_rate: 6.0000e-04
# Epoch 199/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3835 - val_loss: 0.3774 - learning_rate: 6.0000e-04
# Epoch 200/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.3820 - val_loss: 0.3761 - learning_rate: 6.0000e-04
# Epoch 201/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.3807 - val_loss: 0.3749 - learning_rate: 6.0000e-04
# Epoch 202/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3793 - val_loss: 0.3736 - learning_rate: 6.0000e-04
# Epoch 203/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.3780 - val_loss: 0.3722 - learning_rate: 6.0000e-04
# Epoch 204/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3767 - val_loss: 0.3709 - learning_rate: 6.0000e-04
# Epoch 205/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3753 - val_loss: 0.3696 - learning_rate: 6.0000e-04
# Epoch 206/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.3739 - val_loss: 0.3685 - learning_rate: 6.0000e-04
# Epoch 207/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3726 - val_loss: 0.3670 - learning_rate: 6.0000e-04
# Epoch 208/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3713 - val_loss: 0.3658 - learning_rate: 6.0000e-04
# Epoch 209/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.3700 - val_loss: 0.3644 - learning_rate: 6.0000e-04
# Epoch 210/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3686 - val_loss: 0.3632 - learning_rate: 6.0000e-04
# Epoch 211/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.3673 - val_loss: 0.3618 - learning_rate: 6.0000e-04
# Epoch 212/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3660 - val_loss: 0.3607 - learning_rate: 6.0000e-04
# Epoch 213/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3647 - val_loss: 0.3594 - learning_rate: 6.0000e-04
# Epoch 214/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.3634 - val_loss: 0.3581 - learning_rate: 6.0000e-04
# Epoch 215/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.3621 - val_loss: 0.3569 - learning_rate: 6.0000e-04
# Epoch 216/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.3609 - val_loss: 0.3555 - learning_rate: 6.0000e-04
# Epoch 217/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3595 - val_loss: 0.3543 - learning_rate: 6.0000e-04
# Epoch 218/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3582 - val_loss: 0.3531 - learning_rate: 6.0000e-04
# Epoch 219/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.3570 - val_loss: 0.3518 - learning_rate: 6.0000e-04
# Epoch 220/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3558 - val_loss: 0.3507 - learning_rate: 6.0000e-04
# Epoch 221/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.3544 - val_loss: 0.3493 - learning_rate: 6.0000e-04
# Epoch 222/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3532 - val_loss: 0.3482 - learning_rate: 6.0000e-04
# Epoch 223/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.3519 - val_loss: 0.3472 - learning_rate: 6.0000e-04
# Epoch 224/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.3509 - val_loss: 0.3458 - learning_rate: 6.0000e-04
# Epoch 225/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.3494 - val_loss: 0.3446 - learning_rate: 6.0000e-04
# Epoch 226/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.3484 - val_loss: 0.3434 - learning_rate: 6.0000e-04
# Epoch 227/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.3471 - val_loss: 0.3423 - learning_rate: 6.0000e-04
# Epoch 228/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.3459 - val_loss: 0.3412 - learning_rate: 6.0000e-04
# Epoch 229/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3447 - val_loss: 0.3399 - learning_rate: 6.0000e-04
# Epoch 230/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3435 - val_loss: 0.3390 - learning_rate: 6.0000e-04
# Epoch 231/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.3424 - val_loss: 0.3377 - learning_rate: 6.0000e-04
# Epoch 232/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3412 - val_loss: 0.3367 - learning_rate: 6.0000e-04
# Epoch 233/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.3402 - val_loss: 0.3355 - learning_rate: 6.0000e-04
# Epoch 234/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.3389 - val_loss: 0.3344 - learning_rate: 6.0000e-04
# Epoch 235/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.3379 - val_loss: 0.3335 - learning_rate: 6.0000e-04
# Epoch 236/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3367 - val_loss: 0.3324 - learning_rate: 6.0000e-04
# Epoch 237/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.3356 - val_loss: 0.3312 - learning_rate: 6.0000e-04
# Epoch 238/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.3346 - val_loss: 0.3302 - learning_rate: 6.0000e-04
# Epoch 239/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.3334 - val_loss: 0.3291 - learning_rate: 6.0000e-04
# Epoch 240/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.3323 - val_loss: 0.3282 - learning_rate: 6.0000e-04
# Epoch 241/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3312 - val_loss: 0.3272 - learning_rate: 6.0000e-04
# Epoch 242/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.3302 - val_loss: 0.3261 - learning_rate: 6.0000e-04
# Epoch 243/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.3292 - val_loss: 0.3252 - learning_rate: 6.0000e-04
# Epoch 244/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3281 - val_loss: 0.3241 - learning_rate: 6.0000e-04
# Epoch 245/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3270 - val_loss: 0.3231 - learning_rate: 6.0000e-04
# Epoch 246/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.3261 - val_loss: 0.3223 - learning_rate: 6.0000e-04
# Epoch 247/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.3252 - val_loss: 0.3214 - learning_rate: 6.0000e-04
# Epoch 248/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.3240 - val_loss: 0.3203 - learning_rate: 6.0000e-04
# Epoch 249/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.3230 - val_loss: 0.3192 - learning_rate: 6.0000e-04
# Epoch 250/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3219 - val_loss: 0.3183 - learning_rate: 6.0000e-04
# Epoch 251/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.3209 - val_loss: 0.3174 - learning_rate: 6.0000e-04
# Epoch 252/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3199 - val_loss: 0.3165 - learning_rate: 6.0000e-04
# Epoch 253/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.3189 - val_loss: 0.3154 - learning_rate: 6.0000e-04
# Epoch 254/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.3179 - val_loss: 0.3145 - learning_rate: 6.0000e-04
# Epoch 255/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.3168 - val_loss: 0.3135 - learning_rate: 6.0000e-04
# Epoch 256/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3159 - val_loss: 0.3125 - learning_rate: 6.0000e-04
# Epoch 257/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.3149 - val_loss: 0.3115 - learning_rate: 6.0000e-04
# Epoch 258/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.3138 - val_loss: 0.3106 - learning_rate: 6.0000e-04
# Epoch 259/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.3127 - val_loss: 0.3096 - learning_rate: 6.0000e-04
# Epoch 260/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.3117 - val_loss: 0.3086 - learning_rate: 6.0000e-04
# Epoch 261/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.3107 - val_loss: 0.3076 - learning_rate: 6.0000e-04
# Epoch 262/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3096 - val_loss: 0.3066 - learning_rate: 6.0000e-04
# Epoch 263/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.3086 - val_loss: 0.3056 - learning_rate: 6.0000e-04
# Epoch 264/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3076 - val_loss: 0.3047 - learning_rate: 6.0000e-04
# Epoch 265/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3066 - val_loss: 0.3036 - learning_rate: 6.0000e-04
# Epoch 266/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.3056 - val_loss: 0.3026 - learning_rate: 6.0000e-04
# Epoch 267/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.3043 - val_loss: 0.3015 - learning_rate: 6.0000e-04
# Epoch 268/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.3033 - val_loss: 0.3005 - learning_rate: 6.0000e-04
# Epoch 269/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.3024 - val_loss: 0.2996 - learning_rate: 6.0000e-04
# Epoch 270/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.3013 - val_loss: 0.2985 - learning_rate: 6.0000e-04
# Epoch 271/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.3002 - val_loss: 0.2975 - learning_rate: 6.0000e-04
# Epoch 272/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.2991 - val_loss: 0.2966 - learning_rate: 6.0000e-04
# Epoch 273/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2982 - val_loss: 0.2956 - learning_rate: 6.0000e-04
# Epoch 274/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2972 - val_loss: 0.2946 - learning_rate: 6.0000e-04
# Epoch 275/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2963 - val_loss: 0.2937 - learning_rate: 6.0000e-04
# Epoch 276/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2953 - val_loss: 0.2927 - learning_rate: 6.0000e-04
# Epoch 277/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.2944 - val_loss: 0.2919 - learning_rate: 6.0000e-04
# Epoch 278/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2935 - val_loss: 0.2912 - learning_rate: 6.0000e-04
# Epoch 279/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2928 - val_loss: 0.2902 - learning_rate: 6.0000e-04
# Epoch 280/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2919 - val_loss: 0.2894 - learning_rate: 6.0000e-04
# Epoch 281/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.2911 - val_loss: 0.2888 - learning_rate: 6.0000e-04
# Epoch 282/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.2903 - val_loss: 0.2879 - learning_rate: 6.0000e-04
# Epoch 283/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2896 - val_loss: 0.2872 - learning_rate: 6.0000e-04
# Epoch 284/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.2888 - val_loss: 0.2865 - learning_rate: 6.0000e-04
# Epoch 285/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2881 - val_loss: 0.2859 - learning_rate: 6.0000e-04
# Epoch 286/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.2874 - val_loss: 0.2853 - learning_rate: 6.0000e-04
# Epoch 287/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.2868 - val_loss: 0.2846 - learning_rate: 6.0000e-04
# Epoch 288/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2862 - val_loss: 0.2840 - learning_rate: 6.0000e-04
# Epoch 289/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2857 - val_loss: 0.2840 - learning_rate: 6.0000e-04
# Epoch 290/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2851 - val_loss: 0.2831 - learning_rate: 6.0000e-04
# Epoch 291/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2847 - val_loss: 0.2825 - learning_rate: 6.0000e-04
# Epoch 292/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2840 - val_loss: 0.2820 - learning_rate: 6.0000e-04
# Epoch 293/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.2835 - val_loss: 0.2815 - learning_rate: 6.0000e-04
# Epoch 294/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2830 - val_loss: 0.2810 - learning_rate: 6.0000e-04
# Epoch 295/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2825 - val_loss: 0.2806 - learning_rate: 6.0000e-04
# Epoch 296/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.2821 - val_loss: 0.2802 - learning_rate: 6.0000e-04
# Epoch 297/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.2816 - val_loss: 0.2798 - learning_rate: 6.0000e-04
# Epoch 298/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.2812 - val_loss: 0.2793 - learning_rate: 6.0000e-04
# Epoch 299/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.2807 - val_loss: 0.2789 - learning_rate: 6.0000e-04
# Epoch 300/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2803 - val_loss: 0.2786 - learning_rate: 6.0000e-04
# Epoch 301/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2800 - val_loss: 0.2784 - learning_rate: 2.0000e-04
# Epoch 302/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2799 - val_loss: 0.2783 - learning_rate: 2.0000e-04
# Epoch 303/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2797 - val_loss: 0.2782 - learning_rate: 2.0000e-04
# Epoch 304/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2796 - val_loss: 0.2781 - learning_rate: 2.0000e-04
# Epoch 305/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2794 - val_loss: 0.2779 - learning_rate: 2.0000e-04
# Epoch 306/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2793 - val_loss: 0.2778 - learning_rate: 2.0000e-04
# Epoch 307/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.2791 - val_loss: 0.2777 - learning_rate: 2.0000e-04
# Epoch 308/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2791 - val_loss: 0.2775 - learning_rate: 2.0000e-04
# Epoch 309/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2789 - val_loss: 0.2774 - learning_rate: 2.0000e-04
# Epoch 310/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2788 - val_loss: 0.2773 - learning_rate: 2.0000e-04
# Epoch 311/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2786 - val_loss: 0.2772 - learning_rate: 2.0000e-04
# Epoch 312/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2785 - val_loss: 0.2770 - learning_rate: 2.0000e-04
# Epoch 313/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2784 - val_loss: 0.2770 - learning_rate: 2.0000e-04
# Epoch 314/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2782 - val_loss: 0.2768 - learning_rate: 2.0000e-04
# Epoch 315/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.2781 - val_loss: 0.2767 - learning_rate: 2.0000e-04
# Epoch 316/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2779 - val_loss: 0.2766 - learning_rate: 2.0000e-04
# Epoch 317/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2778 - val_loss: 0.2764 - learning_rate: 2.0000e-04
# Epoch 318/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2777 - val_loss: 0.2764 - learning_rate: 2.0000e-04
# Epoch 319/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2776 - val_loss: 0.2762 - learning_rate: 2.0000e-04
# Epoch 320/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.2774 - val_loss: 0.2761 - learning_rate: 2.0000e-04
# Epoch 321/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2773 - val_loss: 0.2759 - learning_rate: 2.0000e-04
# Epoch 322/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2771 - val_loss: 0.2758 - learning_rate: 2.0000e-04
# Epoch 323/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2770 - val_loss: 0.2757 - learning_rate: 2.0000e-04
# Epoch 324/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.2769 - val_loss: 0.2756 - learning_rate: 2.0000e-04
# Epoch 325/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.2768 - val_loss: 0.2755 - learning_rate: 2.0000e-04
# Epoch 326/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.2766 - val_loss: 0.2754 - learning_rate: 2.0000e-04
# Epoch 327/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.2765 - val_loss: 0.2753 - learning_rate: 2.0000e-04
# Epoch 328/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2764 - val_loss: 0.2751 - learning_rate: 2.0000e-04
# Epoch 329/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2762 - val_loss: 0.2750 - learning_rate: 2.0000e-04
# Epoch 330/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.2761 - val_loss: 0.2749 - learning_rate: 2.0000e-04
# Epoch 331/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2760 - val_loss: 0.2748 - learning_rate: 2.0000e-04
# Epoch 332/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2759 - val_loss: 0.2747 - learning_rate: 2.0000e-04
# Epoch 333/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2757 - val_loss: 0.2746 - learning_rate: 2.0000e-04
# Epoch 334/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2756 - val_loss: 0.2744 - learning_rate: 2.0000e-04
# Epoch 335/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2755 - val_loss: 0.2743 - learning_rate: 2.0000e-04
# Epoch 336/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2753 - val_loss: 0.2742 - learning_rate: 2.0000e-04
# Epoch 337/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2752 - val_loss: 0.2741 - learning_rate: 2.0000e-04
# Epoch 338/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2751 - val_loss: 0.2740 - learning_rate: 2.0000e-04
# Epoch 339/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2750 - val_loss: 0.2740 - learning_rate: 2.0000e-04
# Epoch 340/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2748 - val_loss: 0.2738 - learning_rate: 2.0000e-04
# Epoch 341/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2747 - val_loss: 0.2736 - learning_rate: 2.0000e-04
# Epoch 342/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2746 - val_loss: 0.2735 - learning_rate: 2.0000e-04
# Epoch 343/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2745 - val_loss: 0.2734 - learning_rate: 2.0000e-04
# Epoch 344/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2743 - val_loss: 0.2733 - learning_rate: 2.0000e-04
# Epoch 345/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2742 - val_loss: 0.2732 - learning_rate: 2.0000e-04
# Epoch 346/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.2741 - val_loss: 0.2732 - learning_rate: 2.0000e-04
# Epoch 347/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.2739 - val_loss: 0.2729 - learning_rate: 2.0000e-04
# Epoch 348/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2738 - val_loss: 0.2729 - learning_rate: 2.0000e-04
# Epoch 349/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2737 - val_loss: 0.2727 - learning_rate: 2.0000e-04
# Epoch 350/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.2736 - val_loss: 0.2726 - learning_rate: 2.0000e-04
# Epoch 351/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2734 - val_loss: 0.2725 - learning_rate: 2.0000e-04
# Epoch 352/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2733 - val_loss: 0.2724 - learning_rate: 2.0000e-04
# Epoch 353/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.2732 - val_loss: 0.2722 - learning_rate: 2.0000e-04
# Epoch 354/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.2731 - val_loss: 0.2722 - learning_rate: 2.0000e-04
# Epoch 355/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2730 - val_loss: 0.2720 - learning_rate: 2.0000e-04
# Epoch 356/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2728 - val_loss: 0.2720 - learning_rate: 2.0000e-04
# Epoch 357/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2728 - val_loss: 0.2719 - learning_rate: 2.0000e-04
# Epoch 358/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2726 - val_loss: 0.2717 - learning_rate: 2.0000e-04
# Epoch 359/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.2725 - val_loss: 0.2716 - learning_rate: 2.0000e-04
# Epoch 360/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2723 - val_loss: 0.2715 - learning_rate: 2.0000e-04
# Epoch 361/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2722 - val_loss: 0.2714 - learning_rate: 2.0000e-04
# Epoch 362/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.2721 - val_loss: 0.2713 - learning_rate: 2.0000e-04
# Epoch 363/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.2720 - val_loss: 0.2712 - learning_rate: 2.0000e-04
# Epoch 364/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.2719 - val_loss: 0.2710 - learning_rate: 2.0000e-04
# Epoch 365/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2717 - val_loss: 0.2709 - learning_rate: 2.0000e-04
# Epoch 366/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2716 - val_loss: 0.2708 - learning_rate: 2.0000e-04
# Epoch 367/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2715 - val_loss: 0.2707 - learning_rate: 2.0000e-04
# Epoch 368/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2714 - val_loss: 0.2706 - learning_rate: 2.0000e-04
# Epoch 369/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2713 - val_loss: 0.2706 - learning_rate: 2.0000e-04
# Epoch 370/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2711 - val_loss: 0.2704 - learning_rate: 2.0000e-04
# Epoch 371/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2710 - val_loss: 0.2703 - learning_rate: 2.0000e-04
# Epoch 372/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2709 - val_loss: 0.2702 - learning_rate: 2.0000e-04
# Epoch 373/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2708 - val_loss: 0.2701 - learning_rate: 2.0000e-04
# Epoch 374/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2707 - val_loss: 0.2699 - learning_rate: 2.0000e-04
# Epoch 375/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2706 - val_loss: 0.2699 - learning_rate: 2.0000e-04
# Epoch 376/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.2705 - val_loss: 0.2698 - learning_rate: 2.0000e-04
# Epoch 377/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.2704 - val_loss: 0.2696 - learning_rate: 2.0000e-04
# Epoch 378/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2702 - val_loss: 0.2695 - learning_rate: 2.0000e-04
# Epoch 379/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2701 - val_loss: 0.2695 - learning_rate: 2.0000e-04
# Epoch 380/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2700 - val_loss: 0.2693 - learning_rate: 2.0000e-04
# Epoch 381/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2699 - val_loss: 0.2693 - learning_rate: 2.0000e-04
# Epoch 382/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2698 - val_loss: 0.2692 - learning_rate: 2.0000e-04
# Epoch 383/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2697 - val_loss: 0.2690 - learning_rate: 2.0000e-04
# Epoch 384/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.2696 - val_loss: 0.2689 - learning_rate: 2.0000e-04
# Epoch 385/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2695 - val_loss: 0.2688 - learning_rate: 2.0000e-04
# Epoch 386/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2694 - val_loss: 0.2687 - learning_rate: 2.0000e-04
# Epoch 387/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2693 - val_loss: 0.2686 - learning_rate: 2.0000e-04
# Epoch 388/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2692 - val_loss: 0.2685 - learning_rate: 2.0000e-04
# Epoch 389/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2690 - val_loss: 0.2684 - learning_rate: 2.0000e-04
# Epoch 390/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2689 - val_loss: 0.2683 - learning_rate: 2.0000e-04
# Epoch 391/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2688 - val_loss: 0.2682 - learning_rate: 2.0000e-04
# Epoch 392/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.2687 - val_loss: 0.2682 - learning_rate: 2.0000e-04
# Epoch 393/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2687 - val_loss: 0.2680 - learning_rate: 2.0000e-04
# Epoch 394/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2685 - val_loss: 0.2680 - learning_rate: 2.0000e-04
# Epoch 395/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.2684 - val_loss: 0.2678 - learning_rate: 2.0000e-04
# Epoch 396/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2683 - val_loss: 0.2677 - learning_rate: 2.0000e-04
# Epoch 397/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2682 - val_loss: 0.2676 - learning_rate: 2.0000e-04
# Epoch 398/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2681 - val_loss: 0.2675 - learning_rate: 2.0000e-04
# Epoch 399/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2680 - val_loss: 0.2674 - learning_rate: 2.0000e-04
# Epoch 400/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.2679 - val_loss: 0.2673 - learning_rate: 2.0000e-04
# Epoch 401/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.2678 - val_loss: 0.2673 - learning_rate: 5.0000e-05
# Epoch 402/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.2678 - val_loss: 0.2673 - learning_rate: 5.0000e-05
# Epoch 403/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2677 - val_loss: 0.2673 - learning_rate: 5.0000e-05
# Epoch 404/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.2677 - val_loss: 0.2672 - learning_rate: 5.0000e-05
# Epoch 405/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2677 - val_loss: 0.2672 - learning_rate: 5.0000e-05
# Epoch 406/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2676 - val_loss: 0.2672 - learning_rate: 5.0000e-05
# Epoch 407/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.2676 - val_loss: 0.2672 - learning_rate: 5.0000e-05
# Epoch 408/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2676 - val_loss: 0.2671 - learning_rate: 5.0000e-05
# Epoch 409/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2676 - val_loss: 0.2671 - learning_rate: 5.0000e-05
# Epoch 410/3000
# ...
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.2636 - val_loss: 0.2634 - learning_rate: 1.0000e-05
# Epoch 884/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.2636 - val_loss: 0.2634 - learning_rate: 1.0000e-05
# Epoch 885/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2636 - val_loss: 0.2633 - learning_rate: 1.0000e-05
# Epoch 886/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.2636 - val_loss: 0.2633 - learning_rate: 1.0000e-05
# Epoch 887/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2636 - val_loss: 0.2633 - learning_rate: 1.0000e-05
# Epoch 888/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.2636 - val_loss: 0.2633 - learning_rate: 1.0000e-05
# Epoch 889/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.2636 - val_loss: 0.2633 - learning_rate: 1.0000e-05
# Epoch 890/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2636 - val_loss: 0.2633 - learning_rate: 1.0000e-05
# Epoch 891/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.2636 - val_loss: 0.2633 - learning_rate: 1.0000e-05
# Epoch 892/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2636 - val_loss: 0.2633 - learning_rate: 1.0000e-05
# Epoch 893/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2636 - val_loss: 0.2633 - learning_rate: 1.0000e-05
# Epoch 894/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2636 - val_loss: 0.2633 - learning_rate: 1.0000e-05
# Epoch 895/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.2636 - val_loss: 0.2633 - learning_rate: 1.0000e-05
# Epoch 896/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2636 - val_loss: 0.2633 - learning_rate: 1.0000e-05
# Epoch 897/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2636 - val_loss: 0.2633 - learning_rate: 1.0000e-05
# Epoch 898/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.2636 - val_loss: 0.2633 - learning_rate: 1.0000e-05
# Epoch 899/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2636 - val_loss: 0.2633 - learning_rate: 1.0000e-05
# Epoch 900/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2636 - val_loss: 0.2633 - learning_rate: 1.0000e-05
# Epoch 901/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.2636 - val_loss: 0.2633 - learning_rate: 1.0000e-05
# Epoch 902/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2636 - val_loss: 0.2633 - learning_rate: 1.0000e-05
# Epoch 903/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2635 - val_loss: 0.2633 - learning_rate: 1.0000e-05
# Epoch 904/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.2635 - val_loss: 0.2633 - learning_rate: 1.0000e-05
# Epoch 905/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2635 - val_loss: 0.2633 - learning_rate: 1.0000e-05
# Epoch 906/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2635 - val_loss: 0.2633 - learning_rate: 1.0000e-05
# Epoch 907/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2635 - val_loss: 0.2633 - learning_rate: 1.0000e-05
# Epoch 908/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2635 - val_loss: 0.2633 - learning_rate: 1.0000e-05
# Epoch 909/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2635 - val_loss: 0.2633 - learning_rate: 1.0000e-05
# Epoch 910/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2635 - val_loss: 0.2632 - learning_rate: 1.0000e-05
# Epoch 911/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.2635 - val_loss: 0.2632 - learning_rate: 1.0000e-05
# Epoch 912/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.2635 - val_loss: 0.2632 - learning_rate: 1.0000e-05
# Epoch 913/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2635 - val_loss: 0.2632 - learning_rate: 1.0000e-05
# Epoch 914/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.2635 - val_loss: 0.2632 - learning_rate: 1.0000e-05
# Epoch 915/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2635 - val_loss: 0.2632 - learning_rate: 1.0000e-05
# Epoch 916/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2635 - val_loss: 0.2632 - learning_rate: 1.0000e-05
# Epoch 917/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2635 - val_loss: 0.2632 - learning_rate: 1.0000e-05
# Epoch 918/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.2635 - val_loss: 0.2632 - learning_rate: 1.0000e-05
# Epoch 919/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2635 - val_loss: 0.2632 - learning_rate: 1.0000e-05
# Epoch 920/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2635 - val_loss: 0.2632 - learning_rate: 1.0000e-05
# Epoch 921/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2635 - val_loss: 0.2632 - learning_rate: 1.0000e-05
# Epoch 922/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.2635 - val_loss: 0.2632 - learning_rate: 1.0000e-05
# Epoch 923/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.2635 - val_loss: 0.2632 - learning_rate: 1.0000e-05
# Epoch 924/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.2635 - val_loss: 0.2632 - learning_rate: 1.0000e-05
# Epoch 925/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2635 - val_loss: 0.2632 - learning_rate: 1.0000e-05
# Epoch 926/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.2635 - val_loss: 0.2632 - learning_rate: 1.0000e-05
# Epoch 927/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.2635 - val_loss: 0.2632 - learning_rate: 1.0000e-05
# Epoch 928/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.2634 - val_loss: 0.2632 - learning_rate: 1.0000e-05
# Epoch 929/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2634 - val_loss: 0.2632 - learning_rate: 1.0000e-05
# Epoch 930/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2634 - val_loss: 0.2632 - learning_rate: 1.0000e-05
# Epoch 931/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2634 - val_loss: 0.2632 - learning_rate: 1.0000e-05
# Epoch 932/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.2634 - val_loss: 0.2632 - learning_rate: 1.0000e-05
# Epoch 933/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2634 - val_loss: 0.2632 - learning_rate: 1.0000e-05
# Epoch 934/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2634 - val_loss: 0.2632 - learning_rate: 1.0000e-05
# Epoch 935/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2634 - val_loss: 0.2632 - learning_rate: 1.0000e-05
# Epoch 936/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.2634 - val_loss: 0.2631 - learning_rate: 1.0000e-05
# Epoch 937/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2634 - val_loss: 0.2631 - learning_rate: 1.0000e-05
# Epoch 938/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2634 - val_loss: 0.2631 - learning_rate: 1.0000e-05
# Epoch 939/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.2634 - val_loss: 0.2631 - learning_rate: 1.0000e-05
# Epoch 940/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2634 - val_loss: 0.2631 - learning_rate: 1.0000e-05
# Epoch 941/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2634 - val_loss: 0.2631 - learning_rate: 1.0000e-05
# Epoch 942/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.2634 - val_loss: 0.2631 - learning_rate: 1.0000e-05
# Epoch 943/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2634 - val_loss: 0.2631 - learning_rate: 1.0000e-05
# Epoch 944/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2634 - val_loss: 0.2631 - learning_rate: 1.0000e-05
# Epoch 945/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2634 - val_loss: 0.2631 - learning_rate: 1.0000e-05
# Epoch 946/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2634 - val_loss: 0.2631 - learning_rate: 1.0000e-05
# Epoch 947/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2634 - val_loss: 0.2631 - learning_rate: 1.0000e-05
# Epoch 948/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2634 - val_loss: 0.2631 - learning_rate: 1.0000e-05
# Epoch 949/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.2634 - val_loss: 0.2631 - learning_rate: 1.0000e-05
# Epoch 950/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2634 - val_loss: 0.2631 - learning_rate: 1.0000e-05
# Epoch 951/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.2634 - val_loss: 0.2631 - learning_rate: 1.0000e-05
# Epoch 952/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.2634 - val_loss: 0.2631 - learning_rate: 1.0000e-05
# Epoch 953/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.2633 - val_loss: 0.2631 - learning_rate: 1.0000e-05
# Epoch 954/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2633 - val_loss: 0.2631 - learning_rate: 1.0000e-05
# Epoch 955/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2633 - val_loss: 0.2631 - learning_rate: 1.0000e-05
# Epoch 956/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.2633 - val_loss: 0.2631 - learning_rate: 1.0000e-05
# Epoch 957/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2633 - val_loss: 0.2631 - learning_rate: 1.0000e-05
# Epoch 958/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2633 - val_loss: 0.2631 - learning_rate: 1.0000e-05
# Epoch 959/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2633 - val_loss: 0.2631 - learning_rate: 1.0000e-05
# Epoch 960/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2633 - val_loss: 0.2631 - learning_rate: 1.0000e-05
# Epoch 961/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.2633 - val_loss: 0.2630 - learning_rate: 1.0000e-05
# Epoch 962/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2633 - val_loss: 0.2630 - learning_rate: 1.0000e-05
# Epoch 963/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2633 - val_loss: 0.2630 - learning_rate: 1.0000e-05
# Epoch 964/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.2633 - val_loss: 0.2630 - learning_rate: 1.0000e-05
# Epoch 965/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.2633 - val_loss: 0.2630 - learning_rate: 1.0000e-05
# Epoch 966/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2633 - val_loss: 0.2630 - learning_rate: 1.0000e-05
# Epoch 967/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2633 - val_loss: 0.2630 - learning_rate: 1.0000e-05
# Epoch 968/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.2633 - val_loss: 0.2630 - learning_rate: 1.0000e-05
# Epoch 969/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2633 - val_loss: 0.2630 - learning_rate: 1.0000e-05
# Epoch 970/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2633 - val_loss: 0.2630 - learning_rate: 1.0000e-05
# Epoch 971/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2633 - val_loss: 0.2630 - learning_rate: 1.0000e-05
# Epoch 972/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.2633 - val_loss: 0.2630 - learning_rate: 1.0000e-05
# Epoch 973/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.2633 - val_loss: 0.2630 - learning_rate: 1.0000e-05
# Epoch 974/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2633 - val_loss: 0.2630 - learning_rate: 1.0000e-05
# Epoch 975/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2633 - val_loss: 0.2630 - learning_rate: 1.0000e-05
# Epoch 976/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2633 - val_loss: 0.2630 - learning_rate: 1.0000e-05
# Epoch 977/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.2633 - val_loss: 0.2630 - learning_rate: 1.0000e-05
# Epoch 978/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2633 - val_loss: 0.2630 - learning_rate: 1.0000e-05
# Epoch 979/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.2632 - val_loss: 0.2630 - learning_rate: 1.0000e-05
# Epoch 980/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2632 - val_loss: 0.2630 - learning_rate: 1.0000e-05
# Epoch 981/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.2632 - val_loss: 0.2630 - learning_rate: 1.0000e-05
# Epoch 982/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.2632 - val_loss: 0.2630 - learning_rate: 1.0000e-05
# Epoch 983/3000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2632 - val_loss: 0.2630 - learning_rate: 1.0000e-05
# Epoch 984/3000
# 28/30 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2575
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4978/2980433428.py in <cell line: 0>()
#      40 )
#      41 callback = tf.keras.callbacks.LearningRateScheduler(schedulerHenon)
# ---> 42 h = test_model.fit(data, labels, batch_size = 1000, epochs = 3000, validation_split=0.4,verbose=1,callbacks=[callback, early_stop])
#      43
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     421                         shuffle=False,
#     422                     )
# --> 423                 val_logs = self.evaluate(
#     424                     x=val_x,
#     425                     y=val_y,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, return_dict, **kwargs)
#     507         self.reset_metrics()
#     508         with epoch_iterator.catch_stop_iteration():
# --> 509             for begin_step, end_step, iterator in epoch_iterator:
#     510                 callbacks.on_test_batch_begin(begin_step)
#     511                 logs = self.test_function(iterator)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in __next__(self)
#     762
#     763     def __next__(self):
# --> 764         return next(self._epoch_iterator)
#     765
#     766     @contextlib.contextmanager
#
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py in _enumerate_iterator(self)
#     123                 )
#     124             if self._num_batches and self._steps_seen >= self._num_batches:
# --> 125                 self._current_iterator = iter(self._get_iterator())
#     126                 self._steps_seen = 0
#     127         else:
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/data/ops/dataset_ops.py in __iter__(self)
#     499     if context.executing_eagerly() or ops.inside_function():
#     500       with ops.colocate_with(self._variant_tensor):
# --> 501         return iterator_ops.OwnedIterator(self)
#     502     else:
#     503       raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/data/ops/iterator_ops.py in __init__(self, dataset, components, element_spec)
#     707             "When `dataset` is provided, `element_spec` and `components` must "
#     708             "not be specified.")
# --> 709       self._create_iterator(dataset)
#     710
#     711     self._get_next_call_count = 0
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/data/ops/iterator_ops.py in _create_iterator(self, dataset)
#     746             self._flat_output_types)
#     747         self._iterator_resource.op.experimental_set_type(fulltype)
# --> 748       gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#     749
#     750   def __iter__(self):
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/gen_dataset_ops.py in make_iterator(dataset, iterator, name)
#    3476   if tld.is_eager:
#    3477     try:
# -> 3478       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3479         _ctx, "MakeIterator", name, dataset, iterator)
#    3480       return _result
#
# KeyboardInterrupt:

# %%
# Get training loss histories
training_loss = h.history['loss']
validation_loss = h.history["val_loss"]
epoch_count = range(1, len(training_loss) + 1) # Visualize loss history
fig0, ax0 = plt.subplots() 
plt.plot(epoch_count, training_loss, 'r--', label='Training Loss') 
plt.plot(epoch_count, validation_loss, 'b-', label='Validation Loss')
plt.legend() 
ax0.set_title('Loss history') 
plt.yscale('log')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
# Out:
# [ 2.15432112e-05 -1.74011262e-06]

# %%
# same training rows


pred_n = test_model.predict(data, verbose=0)


pred = pred_n * Z_std_selected + Z_mean_selected # only denormalize the x and px coordinates, not the others


truth_n = labels.numpy() if hasattr(labels, "numpy") else np.array(labels)
truth = truth_n * Y_std_selected + Y_mean_selected
inp   = data.numpy()   if hasattr(data, "numpy")   else np.array(data)

print("pred shape:", pred.shape)
print("truth shape:", truth.shape)


identity_mse = np.mean((data - labels)**2)
model_mse = np.mean((pred - labels)**2)

print("identity baseline MSE:", identity_mse)
print("model MSE:", model_mse)
print("improvement factor:", identity_mse / model_mse)

delta_true = labels - data
print("mean |delta_true|:", np.mean(np.abs(delta_true), axis=0))
print("std  |delta_true|:", np.std(delta_true, axis=0))
# Out:
# pred shape: (50000, 2)
# truth shape: (50000, 2)
# identity baseline MSE: 2.6785405042428843
# model MSE: 0.9978570851181059
# improvement factor: 2.6842927150493234
# mean |delta_true|: [1.14790835 1.44609614]
# std  |delta_true|: [1.43999551 1.81204138]

# %%
plot_phase_space_with_profiles(
    [truth[:, 0], pred[:, 0]],
    [truth[:, 1], pred[:, 1]],
    title="HenonNet on training data: truth vs prediction",
    axis_labels=["x", "px"],
    label=["truth", "prediction"],
    bins=120,
    difference=False
)
